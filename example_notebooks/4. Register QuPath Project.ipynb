# %% [markdown]
# # [Aligning Big Brains and Atlases](https://biop.github.io/ijp-imagetoatlas/) in Python
#
# This series of notebook demoes the use of ABBA with python.
#
# If you managed to create an environment with PyImageJ and DeepSlice, you will be able, by running this notebook, to perform an automated registration of a qupath project containind mouse brain sections to the Adult Mouse Allen Brain atlas.
#
# Take care : in this notebook, the slices should be ordered, not flipped, orientated correctly, and you need to adjust the display settings for deepslice to work. Also, it's assumed that channel 0 is DAPI and channel 1 is autofluorescence.
#
# You may download and create a project out of this dataset: https://zenodo.org/record/6553641#.Yz6EHkxBxD8. Remove labels and overview in QuPath before running this notebook
#
# It's probably best not to run it headless to check the project before running the registration
#
#
# Multichannel registration works reasonably well in this notebook because the first channel of the atlas (NISSL, indexed 0), is ressembling the DAPI channel of the slices (indexed 0), and the second channel of the atlas (ARA, indexed 1), is ressembling the autofluorescence channel of the slices (indexed 1).
#
# NOTE : You need to set the elastix and transformix path for the elastix registration steps.

# %%
# core dependencies
import os
import time
from pathlib import Path

from bg_atlasapi import show_atlases
from bg_atlasapi import utils

from abba_python.abba import Abba

# %% [markdown]
# ## 1. ABBA initialization

# %%
headless = False

# -- FOR DEBUGGING
# import imagej.doctor
# imagej.doctor.checkup()
# imagej.doctor.debug_to_stderr()

if headless:
    # -- HEADLESS
    aligner = Abba('Adult Mouse Brain - Allen Brain Atlas V3p1', headless=True)
else:
    # -- NOT HEADLESS
    aligner = Abba('Adult Mouse Brain - Allen Brain Atlas V3p1')
    aligner.show_bdv_ui()  # creates and show a bdv view
# Out:
# [java.lang.Enum.toString] Spimdata mpicbg.spim.data.SpimData@3bea0692 is using the Bdv Playground global cache.
# [java.lang.Enum.toString] [WARNING] Ignoring unsupported output: ba [ch.epfl.biop.atlas.mouse.allen.ccfv3p1.command.AllenBrainAdultMouseAtlasCCF2017v3p1Command]
# [java.lang.Enum.toString] Creating MultiSlicePositioner instance
# [java.lang.Enum.toString] MultiSlicePositioner instance created
# [java.lang.Enum.toString] [WARNING] Ignoring unsupported output: mp [ch.epfl.biop.atlas.aligner.MultiSlicePositioner]
# [java.lang.Enum.toString] Exception in thread "AWT-EventQueue-0" [java.lang.Enum.toString] java.lang.NullPointerException[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Dimension.<init>(Dimension.java:111)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.plaf.basic.BasicProgressBarUI.getPreferredSize(BasicProgressBarUI.java:825)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at com.formdev.flatlaf.ui.FlatProgressBarUI.getPreferredSize(FlatProgressBarUI.java:165)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.plaf.basic.BasicProgressBarUI.getMinimumSize(BasicProgressBarUI.java:875)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.getMinimumSize(JComponent.java:1745)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.swing.SwingComponentWrapper.getMinimumWidth(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid$CompWrap.getSize(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid$CompWrap.validateSize(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid$CompWrap.getSizes(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid$CompWrap.getSize(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid$CompWrap.getSizeInclGaps(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid$CompWrap.access$5300(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid.getTotalSizeParallel(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid.access$4400(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid$LinkedDimGroup.getMinPrefMax(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid$LinkedDimGroup.access$3300(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid.getTotalGroupsSizeParallel(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid.calcRowsOrColsSizes(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid.calcGridSizes(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid.checkSizeCalcs(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid.getWidth(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.layout.Grid.getWidth(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.swing.MigLayout.getSizeImpl(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at net.miginfocom.swing.MigLayout.preferredLayoutSize(Unknown Source)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.preferredSize(Container.java:1797)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.getPreferredSize(Container.java:1781)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.BorderLayout.layoutContainer(BorderLayout.java:821)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.layout(Container.java:1511)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.doLayout(Container.java:1500)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.validateTree(Container.java:1696)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.validate(Container.java:1631)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager$3.run(RepaintManager.java:715)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager$3.run(RepaintManager.java:713)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.security.AccessController.doPrivileged(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager.validateInvalidComponents(RepaintManager.java:712)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager$ProcessingRunnable.run(RepaintManager.java:1842)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.event.InvocationEvent.dispatch(InvocationEvent.java:311)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:762)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventQueue.access$500(EventQueue.java:98)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventQueue$3.run(EventQueue.java:715)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventQueue$3.run(EventQueue.java:709)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.security.AccessController.doPrivileged(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:732)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:201)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:116)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:105)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:93)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.run(EventDispatchThread.java:82)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Exception in thread "AWT-EventQueue-0" [java.lang.Enum.toString] java.lang.NullPointerException[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.plaf.basic.BasicScrollBarUI.layoutVScrollbar(BasicScrollBarUI.java:662)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.plaf.basic.BasicScrollBarUI.layoutContainer(BasicScrollBarUI.java:866)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.layout(Container.java:1511)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.doLayout(Container.java:1500)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.validateTree(Container.java:1696)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.validateTree(Container.java:1705)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.validateTree(Container.java:1705)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.validateTree(Container.java:1705)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.validateTree(Container.java:1705)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.Container.validate(Container.java:1631)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.plaf.basic.BasicTabbedPaneUI.ensureCurrentLayout(BasicTabbedPaneUI.java:1447)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.plaf.basic.BasicTabbedPaneUI.getTabRunCount(BasicTabbedPaneUI.java:1473)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at com.formdev.flatlaf.ui.FlatTabbedPaneUI.ensureCurrentLayout(FlatTabbedPaneUI.java:1530)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at com.formdev.flatlaf.ui.FlatTabbedPaneUI.paint(FlatTabbedPaneUI.java:979)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.plaf.ComponentUI.update(ComponentUI.java:161)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at com.formdev.flatlaf.ui.FlatTabbedPaneUI.update(FlatTabbedPaneUI.java:968)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.paintComponent(JComponent.java:780)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.paint(JComponent.java:1057)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.paintChildren(JComponent.java:890)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.paint(JComponent.java:1066)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.paintChildren(JComponent.java:890)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.paint(JComponent.java:1066)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JLayeredPane.paint(JLayeredPane.java:586)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.paintChildren(JComponent.java:890)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.paint(JComponent.java:1066)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.paintToOffscreen(JComponent.java:5211)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager$PaintManager.paintDoubleBufferedImpl(RepaintManager.java:1596)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager$PaintManager.paintDoubleBuffered(RepaintManager.java:1571)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager$PaintManager.paint(RepaintManager.java:1509)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager.paint(RepaintManager.java:1276)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent._paintImmediately(JComponent.java:5159)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.JComponent.paintImmediately(JComponent.java:4970)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager$4.run(RepaintManager.java:835)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager$4.run(RepaintManager.java:818)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.security.AccessController.doPrivileged(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager.paintDirtyRegions(RepaintManager.java:818)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager.paintDirtyRegions(RepaintManager.java:793)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager.prePaintDirtyRegions(RepaintManager.java:742)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager.access$1200(RepaintManager.java:68)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at javax.swing.RepaintManager$ProcessingRunnable.run(RepaintManager.java:1843)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.event.InvocationEvent.dispatch(InvocationEvent.java:311)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:762)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventQueue.access$500(EventQueue.java:98)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventQueue$3.run(EventQueue.java:715)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventQueue$3.run(EventQueue.java:709)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.security.AccessController.doPrivileged(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:732)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:201)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:116)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:105)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:93)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.awt.EventDispatchThread.run(EventDispatchThread.java:82)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Keymap list file C:\Users\chiarutt\AppData\Roaming\fiji\bigdataviewer\config\keymaps\keymaps.yaml not found. Using builtin styles.[java.lang.Enum.toString]
# [java.lang.Enum.toString] Appearance settings file C:\Users\chiarutt\AppData\Roaming\fiji\bigdataviewer\config/appearance.yaml not found. Using defaults.[java.lang.Enum.toString]
# [java.lang.Enum.toString] Registration plugin RegisterSlicesElastixAffineCommand discovered
# [java.lang.Enum.toString] Registration plugin RegisterSlicesBigWarpCommand discovered
# [java.lang.Enum.toString] Registration plugin MirrorDoCommand discovered
# [java.lang.Enum.toString] Registration plugin RegisterSlicesElastixSplineCommand discovered
# nSlices = 97
# WARNING:tensorflow:From C:\Users\chiarutt\.conda\envs\test_abba_pip6\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Found 97 validated image filenames.
# 97/97 [==============================] - 10s 108ms/step

# %% [markdown]
# ## 2. Loading QuPath project

# %%
aligner.import_slices_from_qupath(slice_axis_initial_mm = 0.2,
                               increment_between_slices_mm = 0.08,
                               qupath_project= 'C:/Users/chiarutt/Desktop/abba-omero/abba-omero/project.qpproj') #'C:/Users/chiarutt/Desktop/ABBA_Workshop/PCB06-DemoProject/project.qpproj')
# Out:
# [java.lang.Enum.toString] The OMERO session for omero-server.epfl.ch needs to be initialized[java.lang.Enum.toString]
# [java.lang.Enum.toString] Session active : true
# [java.lang.Enum.toString] [ERROR] Exception during event handling:
# 	[Event] org.scijava.display.event.DisplayActivatedEvent
# 	context = org.scijava.Context@76889e60
# 	consumed = false
# 	display = plugin:org.scijava.table.DefaultTableDisplay: type=interface org.scijava.table.Table, name=Omero - Connect, objects={[[success], [true]]}
# 	[Subscriber] Foreground
# 	[Method] protected void net.imagej.plugins.tools.AbstractColorTool.onEvent(org.scijava.display.event.DisplayActivatedEvent)
# java.lang.AbstractMethodError: Method net/imagej/legacy/display/LegacyImageDisplayService.getActiveDatasetView()Lnet/imagej/display/DatasetView; is abstract
# 	at net.imagej.legacy.display.LegacyImageDisplayService.getActiveDatasetView(LegacyImageDisplayService.java)
# 	at net.imagej.plugins.tools.AbstractColorTool.drawIcon(AbstractColorTool.java:167)
# 	at net.imagej.plugins.tools.AbstractColorTool.onEvent(AbstractColorTool.java:181)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.display.DefaultDisplayService.setActiveDisplay(DefaultDisplayService.java:123)
# 	at org.scijava.display.DefaultDisplayService.onEvent(DefaultDisplayService.java:248)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.ui.awt.AWTWindowEventDispatcher.windowActivated(AWTWindowEventDispatcher.java:90)
# 	at java.awt.AWTEventMulticaster.windowActivated(AWTEventMulticaster.java:389)
# 	at java.awt.Window.processWindowEvent(Window.java:2066)
# 	at javax.swing.JFrame.processWindowEvent(JFrame.java:305)
# 	at java.awt.Window.processEvent(Window.java:2013)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4897)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.KeyboardFocusManager.redispatchEvent(KeyboardFocusManager.java:1954)
# 	at java.awt.DefaultKeyboardFocusManager.typeAheadAssertions(DefaultKeyboardFocusManager.java:995)
# 	at java.awt.DefaultKeyboardFocusManager.dispatchEvent(DefaultKeyboardFocusManager.java:488)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4768)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:764)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.SentEvent.dispatch(SentEvent.java:70)
# 	at java.awt.DefaultKeyboardFocusManager$DefaultKeyboardFocusManagerSentEvent.dispatch(DefaultKeyboardFocusManager.java:217)
# 	at java.awt.DefaultKeyboardFocusManager.sendMessage(DefaultKeyboardFocusManager.java:244)
# 	at java.awt.DefaultKeyboardFocusManager.dispatchEvent(DefaultKeyboardFocusManager.java:366)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4768)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:764)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.SequencedEvent.dispatch(SequencedEvent.java:128)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:762)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:201)
# 	at java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:116)
# 	at java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:105)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:93)
# 	at java.awt.EventDispatchThread.run(EventDispatchThread.java:82)
# [java.lang.Enum.toString] [ERROR] Exception during event handling:
# 	[Event] org.scijava.display.event.DisplayActivatedEvent
# 	context = org.scijava.Context@76889e60
# 	consumed = false
# 	display = plugin:org.scijava.table.DefaultTableDisplay: type=interface org.scijava.table.Table, name=Omero - Connect, objects={[[success], [true]]}
# 	[Subscriber] Background
# 	[Method] protected void net.imagej.plugins.tools.AbstractColorTool.onEvent(org.scijava.display.event.DisplayActivatedEvent)
# java.lang.AbstractMethodError: Method net/imagej/legacy/display/LegacyImageDisplayService.getActiveDatasetView()Lnet/imagej/display/DatasetView; is abstract
# 	at net.imagej.legacy.display.LegacyImageDisplayService.getActiveDatasetView(LegacyImageDisplayService.java)
# 	at net.imagej.plugins.tools.AbstractColorTool.drawIcon(AbstractColorTool.java:167)
# 	at net.imagej.plugins.tools.AbstractColorTool.onEvent(AbstractColorTool.java:181)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.display.DefaultDisplayService.setActiveDisplay(DefaultDisplayService.java:123)
# 	at org.scijava.display.DefaultDisplayService.onEvent(DefaultDisplayService.java:248)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.ui.awt.AWTWindowEventDispatcher.windowActivated(AWTWindowEventDispatcher.java:90)
# 	at java.awt.AWTEventMulticaster.windowActivated(AWTEventMulticaster.java:389)
# 	at java.awt.Window.processWindowEvent(Window.java:2066)
# 	at javax.swing.JFrame.processWindowEvent(JFrame.java:305)
# 	at java.awt.Window.processEvent(Window.java:2013)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4897)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.KeyboardFocusManager.redispatchEvent(KeyboardFocusManager.java:1954)
# 	at java.awt.DefaultKeyboardFocusManager.typeAheadAssertions(DefaultKeyboardFocusManager.java:995)
# 	at java.awt.DefaultKeyboardFocusManager.dispatchEvent(DefaultKeyboardFocusManager.java:488)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4768)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:764)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.SentEvent.dispatch(SentEvent.java:70)
# 	at java.awt.DefaultKeyboardFocusManager$DefaultKeyboardFocusManagerSentEvent.dispatch(DefaultKeyboardFocusManager.java:217)
# 	at java.awt.DefaultKeyboardFocusManager.sendMessage(DefaultKeyboardFocusManager.java:244)
# 	at java.awt.DefaultKeyboardFocusManager.dispatchEvent(DefaultKeyboardFocusManager.java:366)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4768)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:764)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.SequencedEvent.dispatch(SequencedEvent.java:128)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:762)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:201)
# 	at java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:116)
# 	at java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:105)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:93)
# 	at java.awt.EventDispatchThread.run(EventDispatchThread.java:82)
# [java.lang.Enum.toString] [WARNING] Ignoring unsupported output: omeroSession [net.imagej.omero.OMEROSession]
# [java.lang.Enum.toString] [ERROR] Exception during event handling:
# 	[Event] org.scijava.display.event.DisplayActivatedEvent
# 	context = org.scijava.Context@76889e60
# 	consumed = false
# 	display = plugin:org.scijava.table.DefaultTableDisplay: type=interface org.scijava.table.Table, name=Omero - Connect, objects={[[success], [true]]}
# 	[Subscriber] Foreground
# 	[Method] protected void net.imagej.plugins.tools.AbstractColorTool.onEvent(org.scijava.display.event.DisplayActivatedEvent)
# java.lang.AbstractMethodError: Method net/imagej/legacy/display/LegacyImageDisplayService.getActiveDatasetView()Lnet/imagej/display/DatasetView; is abstract
# 	at net.imagej.legacy.display.LegacyImageDisplayService.getActiveDatasetView(LegacyImageDisplayService.java)
# 	at net.imagej.plugins.tools.AbstractColorTool.drawIcon(AbstractColorTool.java:167)
# 	at net.imagej.plugins.tools.AbstractColorTool.onEvent(AbstractColorTool.java:181)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.display.DefaultDisplayService.setActiveDisplay(DefaultDisplayService.java:123)
# 	at org.scijava.display.DefaultDisplayService.onEvent(DefaultDisplayService.java:248)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.ui.awt.AWTWindowEventDispatcher.windowActivated(AWTWindowEventDispatcher.java:90)
# 	at java.awt.AWTEventMulticaster.windowActivated(AWTEventMulticaster.java:389)
# 	at java.awt.Window.processWindowEvent(Window.java:2066)
# 	at javax.swing.JFrame.processWindowEvent(JFrame.java:305)
# 	at java.awt.Window.processEvent(Window.java:2013)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4897)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.KeyboardFocusManager.redispatchEvent(KeyboardFocusManager.java:1954)
# 	at java.awt.DefaultKeyboardFocusManager.typeAheadAssertions(DefaultKeyboardFocusManager.java:995)
# 	at java.awt.DefaultKeyboardFocusManager.dispatchEvent(DefaultKeyboardFocusManager.java:488)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4768)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:764)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.SentEvent.dispatch(SentEvent.java:70)
# 	at java.awt.DefaultKeyboardFocusManager$DefaultKeyboardFocusManagerSentEvent.dispatch(DefaultKeyboardFocusManager.java:217)
# 	at java.awt.DefaultKeyboardFocusManager.sendMessage(DefaultKeyboardFocusManager.java:244)
# 	at java.awt.DefaultKeyboardFocusManager.dispatchEvent(DefaultKeyboardFocusManager.java:366)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4768)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:764)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.SequencedEvent.dispatch(SequencedEvent.java:128)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:762)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:201)
# 	at java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:116)
# 	at java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:105)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:93)
# 	at java.awt.EventDispatchThread.run(EventDispatchThread.java:82)
# [java.lang.Enum.toString] [ERROR] Exception during event handling:
# 	[Event] org.scijava.display.event.DisplayActivatedEvent
# 	context = org.scijava.Context@76889e60
# 	consumed = false
# 	display = plugin:org.scijava.table.DefaultTableDisplay: type=interface org.scijava.table.Table, name=Omero - Connect, objects={[[success], [true]]}
# 	[Subscriber] Background
# 	[Method] protected void net.imagej.plugins.tools.AbstractColorTool.onEvent(org.scijava.display.event.DisplayActivatedEvent)
# java.lang.AbstractMethodError: Method net/imagej/legacy/display/LegacyImageDisplayService.getActiveDatasetView()Lnet/imagej/display/DatasetView; is abstract
# 	at net.imagej.legacy.display.LegacyImageDisplayService.getActiveDatasetView(LegacyImageDisplayService.java)
# 	at net.imagej.plugins.tools.AbstractColorTool.drawIcon(AbstractColorTool.java:167)
# 	at net.imagej.plugins.tools.AbstractColorTool.onEvent(AbstractColorTool.java:181)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.display.DefaultDisplayService.setActiveDisplay(DefaultDisplayService.java:123)
# 	at org.scijava.display.DefaultDisplayService.onEvent(DefaultDisplayService.java:248)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.ui.awt.AWTWindowEventDispatcher.windowActivated(AWTWindowEventDispatcher.java:90)
# 	at java.awt.AWTEventMulticaster.windowActivated(AWTEventMulticaster.java:389)
# 	at java.awt.Window.processWindowEvent(Window.java:2066)
# 	at javax.swing.JFrame.processWindowEvent(JFrame.java:305)
# 	at java.awt.Window.processEvent(Window.java:2013)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4897)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.KeyboardFocusManager.redispatchEvent(KeyboardFocusManager.java:1954)
# 	at java.awt.DefaultKeyboardFocusManager.typeAheadAssertions(DefaultKeyboardFocusManager.java:995)
# 	at java.awt.DefaultKeyboardFocusManager.dispatchEvent(DefaultKeyboardFocusManager.java:488)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4768)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:764)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.SentEvent.dispatch(SentEvent.java:70)
# 	at java.awt.DefaultKeyboardFocusManager$DefaultKeyboardFocusManagerSentEvent.dispatch(DefaultKeyboardFocusManager.java:217)
# 	at java.awt.DefaultKeyboardFocusManager.sendMessage(DefaultKeyboardFocusManager.java:244)
# 	at java.awt.DefaultKeyboardFocusManager.dispatchEvent(DefaultKeyboardFocusManager.java:366)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4768)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:764)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.SequencedEvent.dispatch(SequencedEvent.java:128)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:762)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:201)
# 	at java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:116)
# 	at java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:105)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:93)
# 	at java.awt.EventDispatchThread.run(EventDispatchThread.java:82)
# [java.lang.Enum.toString] [ERROR] Exception during event handling:
# 	[Event] org.scijava.display.event.DisplayDeletedEvent
# 	context = org.scijava.Context@76889e60
# 	consumed = false
# 	object = plugin:org.scijava.table.DefaultTableDisplay: type=interface org.scijava.table.Table, name=Omero - Connect, objects={[[success], [true]]}
# 	[Subscriber] Foreground
# 	[Method] protected void net.imagej.plugins.tools.AbstractColorTool.onEvent(org.scijava.display.event.DisplayDeletedEvent)
# java.lang.AbstractMethodError: Method net/imagej/legacy/display/LegacyImageDisplayService.getActiveDatasetView()Lnet/imagej/display/DatasetView; is abstract
# 	at net.imagej.legacy.display.LegacyImageDisplayService.getActiveDatasetView(LegacyImageDisplayService.java)
# 	at net.imagej.plugins.tools.AbstractColorTool.drawIcon(AbstractColorTool.java:167)
# 	at net.imagej.plugins.tools.AbstractColorTool.onEvent(AbstractColorTool.java:186)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.display.AbstractDisplay.close(AbstractDisplay.java:135)
# 	at org.scijava.display.DefaultDisplayService.onEvent(DefaultDisplayService.java:241)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.ui.awt.AWTWindowEventDispatcher.windowClosed(AWTWindowEventDispatcher.java:95)
# 	at java.awt.Window.processWindowEvent(Window.java:2057)
# 	at javax.swing.JFrame.processWindowEvent(JFrame.java:305)
# 	at java.awt.Window.processEvent(Window.java:2013)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4897)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:764)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:201)
# 	at java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:116)
# 	at java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:105)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:93)
# 	at java.awt.EventDispatchThread.run(EventDispatchThread.java:82)
# [java.lang.Enum.toString] [ERROR] Exception during event handling:
# 	[Event] org.scijava.display.event.DisplayDeletedEvent
# 	context = org.scijava.Context@76889e60
# 	consumed = false
# 	object = plugin:org.scijava.table.DefaultTableDisplay: type=interface org.scijava.table.Table, name=Omero - Connect, objects={[[success], [true]]}
# 	[Subscriber] Background
# 	[Method] protected void net.imagej.plugins.tools.AbstractColorTool.onEvent(org.scijava.display.event.DisplayDeletedEvent)
# java.lang.AbstractMethodError: Method net/imagej/legacy/display/LegacyImageDisplayService.getActiveDatasetView()Lnet/imagej/display/DatasetView; is abstract
# 	at net.imagej.legacy.display.LegacyImageDisplayService.getActiveDatasetView(LegacyImageDisplayService.java)
# 	at net.imagej.plugins.tools.AbstractColorTool.drawIcon(AbstractColorTool.java:167)
# 	at net.imagej.plugins.tools.AbstractColorTool.onEvent(AbstractColorTool.java:186)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.display.AbstractDisplay.close(AbstractDisplay.java:135)
# 	at org.scijava.display.DefaultDisplayService.onEvent(DefaultDisplayService.java:241)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:298)
# 	at org.scijava.event.DefaultEventService$ProxySubscriber.onEvent(DefaultEventService.java:272)
# 	at org.bushe.swing.event.ThreadSafeEventService.publish(ThreadSafeEventService.java:971)
# 	at org.scijava.event.DefaultEventBus.access$101(DefaultEventBus.java:54)
# 	at org.scijava.event.DefaultEventBus$1.run(DefaultEventBus.java:188)
# 	at org.scijava.thread.DefaultThreadService.invoke(DefaultThreadService.java:111)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:182)
# 	at org.scijava.event.DefaultEventBus.publishNow(DefaultEventBus.java:73)
# 	at org.scijava.event.DefaultEventService.publish(DefaultEventService.java:102)
# 	at org.scijava.ui.awt.AWTWindowEventDispatcher.windowClosed(AWTWindowEventDispatcher.java:95)
# 	at java.awt.Window.processWindowEvent(Window.java:2057)
# 	at javax.swing.JFrame.processWindowEvent(JFrame.java:305)
# 	at java.awt.Window.processEvent(Window.java:2013)
# 	at java.awt.Component.dispatchEventImpl(Component.java:4897)
# 	at java.awt.Container.dispatchEventImpl(Container.java:2295)
# 	at java.awt.Window.dispatchEventImpl(Window.java:2746)
# 	at java.awt.Component.dispatchEvent(Component.java:4719)
# 	at java.awt.EventQueue.dispatchEventImpl(EventQueue.java:764)
# 	at java.awt.EventQueue.access$500(EventQueue.java:98)
# 	at java.awt.EventQueue$3.run(EventQueue.java:715)
# 	at java.awt.EventQueue$3.run(EventQueue.java:709)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:90)
# 	at java.awt.EventQueue$4.run(EventQueue.java:737)
# 	at java.awt.EventQueue$4.run(EventQueue.java:735)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:80)
# 	at java.awt.EventQueue.dispatchEvent(EventQueue.java:734)
# 	at java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:201)
# 	at java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:116)
# 	at java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:105)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)
# 	at java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:93)
# 	at java.awt.EventDispatchThread.run(EventDispatchThread.java:82)
# [java.lang.Enum.toString] Spimdata mpicbg.spim.data.SpimData@3a861475 is using the Bdv Playground global cache.
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_01]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_01] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_02]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_02] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_03]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_03] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_04]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_04] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_05]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_05] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_06]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_06] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_07]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_07] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_08]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_08] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_09]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_09] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_10]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_10] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_11]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_11] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_12]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_12] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_13]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_13] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_14]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_14] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_15]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_15] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_16]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_16] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_17]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_17] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_18]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_18] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_19]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_19] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_20]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_20] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_21]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_21] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_00.vsi [10x_22]...
# [java.lang.Enum.toString] Slice Slide_00.vsi [10x_22] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_01]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_01] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_02]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_02] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_03]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_03] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_04]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_04] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_05]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_05] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_06]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_06] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_07]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_07] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_08]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_08] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_09]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_09] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_10]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_10] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_11]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_11] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_12]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_12] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_13]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_13] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_14]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_14] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_15]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_15] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_16]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_16] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_01.vsi [10x_17]...
# [java.lang.Enum.toString] Slice Slide_01.vsi [10x_17] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_01]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_01] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_02]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_02] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_03]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_03] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_04]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_04] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_05]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_05] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_06]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_06] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_07]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_07] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Error : actions null for slice Slide_02.vsi [10x_07][java.lang.Enum.toString]
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_08]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_08] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_09]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_09] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_10]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_10] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_11]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_11] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_12]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_12] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_02.vsi [10x_13]...
# [java.lang.Enum.toString] Slice Slide_02.vsi [10x_13] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_01]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_01] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_02]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_02] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_03]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_03] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_04]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_04] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_05]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_05] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_06]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_06] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_07]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_07] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_08]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_08] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_09]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_09] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_10]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_10] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_11]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_11] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_03.vsi [10x_12]...
# [java.lang.Enum.toString] Slice Slide_03.vsi [10x_12] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_01]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_01] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_02]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_02] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_03]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_03] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_04]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_04] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_05]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_05] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_06]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_06] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_07]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_07] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_08]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_08] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_09]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_09] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_10]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_10] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_11]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_11] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_04.vsi [10x_12]...
# [java.lang.Enum.toString] Slice Slide_04.vsi [10x_12] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_01]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_01] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_02]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_02] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_03]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_03] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_04]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_04] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_05]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_05] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_06]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_06] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_07]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_07] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_08]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_08] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_09]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_09] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_10]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_10] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_11]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_11] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_05.vsi [10x_12]...
# [java.lang.Enum.toString] Slice Slide_05.vsi [10x_12] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_06.vsi [10x_01]...
# [java.lang.Enum.toString] Slice Slide_06.vsi [10x_01] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_06.vsi [10x_02]...
# [java.lang.Enum.toString] Slice Slide_06.vsi [10x_02] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_06.vsi [10x_03]...
# [java.lang.Enum.toString] Slice Slide_06.vsi [10x_03] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_06.vsi [10x_04]...
# [java.lang.Enum.toString] Slice Slide_06.vsi [10x_04] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_06.vsi [10x_05]...
# [java.lang.Enum.toString] Slice Slide_06.vsi [10x_05] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_06.vsi [10x_06]...
# [java.lang.Enum.toString] Slice Slide_06.vsi [10x_06] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_06.vsi [10x_07]...
# [java.lang.Enum.toString] Slice Slide_06.vsi [10x_07] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_06.vsi [10x_08]...
# [java.lang.Enum.toString] Slice Slide_06.vsi [10x_08] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] Creating slice Slide_06.vsi [10x_09]...
# [java.lang.Enum.toString] Slice Slide_06.vsi [10x_09] created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# <java object 'org.scijava.command.CommandModule'>

# %%
print('nSlices = '+str(aligner.mp.getSlices().size()))
# ALL REGISTRATIONS AND COMMANDS BELOW ARE PERFORMED ON THE SELECTED SLICES!!
# since we want to register all of them, we select all of them
aligner.select_all_slices()

# %%
# we want to avoid saturation in the display. This does not matter for
# all registration methods EXCEPT for DeepSlice, which takes in rgb images
aligner.select_all_slices()
aligner.change_display_settings(0, 0, 800)
#abba.change_display_settings(1, 0, 1200) # fails because some slices have no channel 1

# programmatic way to show (or hide) sections and channels
aligner.get_bdv_view().setSelectedSlicesVisibility(True)
aligner.get_bdv_view().setSelectedSlicesVisibility(0, True)

# %% [markdown]
# ## 4. DeepSlice Registration(s)

# %%
# REMOVE LABELS AND OVERVIEWS!!

# a first deepslice registration round : possible because it's the Allen CCF atlas, cut in coronal mode
# what's assumed : the sections are already in the correct order
aligner.register_slices_deepslice(channels=[0, 1])
# Out:
# <java object 'org.scijava.command.CommandModule'>
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_18] done (18/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_10] done (32/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_06] done (70/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_16] done (16/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_09] done (31/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_12] done (64/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_10] done (62/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_11] done (33/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_08] done (8/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_04] done (56/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_14] done (14/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_05] done (44/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_22] done (22/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_13] done (35/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_12] done (88/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_06] done (28/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_04] done (4/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_04] done (68/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_02] done (2/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_09] done (9/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_02] done (24/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_04] done (26/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_02] done (66/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_06.vsi [10x_02] done (90/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_14] done (36/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_11] done (63/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_17] done (17/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_06] done (45/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_08] done (72/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_08] done (30/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_05] done (57/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_15] done (15/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_06] done (6/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_05] done (69/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_07] done (29/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_01] done (23/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_05] done (27/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_03] done (3/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_07] done (7/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_04] done (43/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_06.vsi [10x_01] done (89/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_01] done (65/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_13] done (13/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_09] done (61/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_12] done (34/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_03] done (55/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_13] done (52/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_07] done (71/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_03] done (67/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_05] done (5/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_06] done (58/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_01] done (1/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_03] done (25/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_07] done (59/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_20] done (20/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_10] done (86/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_10] done (10/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_04] done (80/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_08] done (47/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_11] done (11/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_01] done (40/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_07] done (46/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_12] done (12/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_19] done (19/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_09] done (85/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_09] done (48/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_03] done (42/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_06.vsi [10x_09] done (97/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_08] done (60/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_11] done (87/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_05] done (81/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_11] done (50/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_06.vsi [10x_07] done (95/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_01] done (53/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_03.vsi [10x_02] done (54/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_00.vsi [10x_21] done (21/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_10] done (49/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_06.vsi [10x_04] done (92/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_06.vsi [10x_03] done (91/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_12] done (76/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_06.vsi [10x_05] done (93/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_02] done (41/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_16] done (38/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_02.vsi [10x_12] done (51/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_07] done (83/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_08] done (84/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_06.vsi [10x_06] done (94/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_06] done (82/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_17] done (39/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_03] done (79/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_06.vsi [10x_08] done (96/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_01.vsi [10x_15] done (37/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_10] done (74/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_02] done (78/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_09] done (73/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_04.vsi [10x_11] done (75/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export of slice Slide_05.vsi [10x_01] done (77/97)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Export as QuickNii Dataset done - Folder : C:\Users\chiarutt\AppData\Local\Temp\temp\deepslice[java.lang.Enum.toString]
# [java.lang.Enum.toString] Multipositioner : Slicing angle adjusted to Angle X : 0.0 has been updated to 0.041
# Angle Y : 0.0 has been updated to 0.003

# %%
# second deepslice registration: because the slices are resampled for the registration,
# we usually get a slightly better positioning along z and cutting angle
# also: it's fast, and the combination of two affine transforms is
# an affine transform, so it's not like we are adding extra degrees of freedom
aligner.register_slices_deepslice(channels=[0, 1])

# %% [markdown]
# ## 5. Elastix affine registration

# %%
# a round of elastix registration, affine
# the channel 0 of the dataset (DAPI) is registered with the Nissl Channel of the atlas (0)
# and the channel 1 of the dataset (mainly autofluo) is registered with the autofluo channel of the atlas (1)
# these two channels have equal weights in the registration process
aligner.register_slices_elastix_affine(channels_slice_csv='0,1',
                                    channels_atlas_csv='0,1',
                                    pixel_size_micrometer=40)

# %% [markdown]
# ## 6. Elastix spline registration

# %%
# optional: a round of elastix registration, spline
# same channels as in the affine registration
# 5 control points along x = very coarse spline (and thus maybe unnecessary)
# abba.register_elastix_spline(
#    nb_control_points=5,
#    atlas_image_channels=[0, 1],
#    slice_image_channels=[0, 1],
#    pixel_size_micrometer=40).get()

# a round of elastix registration, affine
# same channels as in the affine registration 
# 16 control points = reasonable spline, which allows for local corrections, without deforming two much the section
aligner.register_slices_elastix_spline(channels_slice_csv='0,1',
                                    channels_atlas_csv='0,1',
                                    nb_control_points_x=16,
                                    pixel_size_micrometer=20)

# %% [markdown]
# ## 7. Wait for end of all registrations

# %%
# all tasks/registrations are enqueued and executed asynchronously
# if you need to wait before saving, then wait for all tasks to be finished:
aligner.wait_for_end_of_tasks()

# %%
aligner.export_registration_to_qupath(erase_previous_file=True)

# %%
# all tasks/registrations/exports are enqueued and executed asynchronously
# if you need to wait before saving, then wait for all tasks to be finished:
aligner.wait_for_end_of_tasks()

# %% [markdown]
# ## 8. Saving the result

# %%
save_dir = os.path.join(os.getcwd(), 'temp', 'notebook4', 'state')

if not os.path.exists(save_dir):
    os.makedirs(save_dir)


aligner.state_save(save_dir+"/state.abba") # full absolute path needed
